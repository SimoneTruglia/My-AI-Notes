# %% [markdown]
# **Esercitazione**
# Provare a completare il notebook, seguendo le indicazioni fornite.
# Il notebook è fornito già eseguito, in modo da poter sfruttare l'output generato da ogni cella per
# verificare la correttezza della risoluzione.
# Alcune parti di codice sono state sostituite da tre punti consecutivi.
#
#
# ### Dataset sulla qualità dei vini
#
# *Questo set di dati è correlato alle varianti rosse del vino portoghese
# "Vinho Verde". Il set di dati descrive la quantità di varie sostanze
# chimiche presenti nel vino e permette di identificare il loro effetto
# sulla sua qualità.
# Il dataset è disponibile su Kaggle alla url
# https://www.kaggle.com/datasets/yasserh/wine-quality-dataset*

# %%
# importazione librerie necessarie

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.utils import shuffle
# Out:
# 2023-05-10 18:05:30.963307: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-05-10 18:05:37.685832: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-10 18:05:37.808199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-10 18:05:37.808261: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# caricamento dataset in memoria

# utilizzare il metodo [read_csv] dei dataframe di Pandas
# per caricare il file disponibile all'indirizzo
# 'data/WineQT.csv'

df = pd.read_csv('data/WineQT.csv')

# %%
# visualizzazione delle prime 10 righe del dataset
# utilizzando uno stile per il background delle celle
# in grado di evidenziare i valori minimi e massimi
# tramite gradienti di colore che vanno dal bianco
# all'arancione, sfruttando il metodo:
# https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.background_gradient.html

color_map = sns.light_palette('orange', as_cmap=True)

df.head(10).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_67dd3_row0_col0, #T_67dd3_row4_col0, #T_67dd3_row5_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_67dd3_row0_col1, #T_67dd3_row4_col1, #T_67dd3_row7_col12 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_67dd3_row0_col2, #T_67dd3_row0_col11, #T_67dd3_row0_col12, #T_67dd3_row1_col2, #T_67dd3_row1_col11, #T_67dd3_row2_col11, #T_67dd3_row3_col1, #T_67dd3_row3_col8, #T_67dd3_row4_col2, #T_67dd3_row4_col11, #T_67dd3_row5_col2, #T_67dd3_row5_col11, #T_67dd3_row6_col9, #T_67dd3_row6_col11, #T_67dd3_row7_col2, #T_67dd3_row7_col3, #T_67dd3_row7_col4, #T_67dd3_row7_col7, #T_67dd3_row8_col5, #T_67dd3_row8_col6, #T_67dd3_row9_col0, #T_67dd3_row9_col10, #T_67dd3_row9_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_67dd3_row0_col3, #T_67dd3_row3_col3, #T_67dd3_row4_col3, #T_67dd3_row8_col1, #T_67dd3_row8_col9, #T_67dd3_row9_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_67dd3_row0_col4, #T_67dd3_row4_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_67dd3_row0_col5, #T_67dd3_row4_col5 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_67dd3_row0_col6, #T_67dd3_row4_col6 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_67dd3_row0_col7, #T_67dd3_row4_col7, #T_67dd3_row5_col7 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_67dd3_row0_col8, #T_67dd3_row1_col1, #T_67dd3_row1_col3, #T_67dd3_row1_col4, #T_67dd3_row1_col5, #T_67dd3_row1_col6, #T_67dd3_row1_col9, #T_67dd3_row3_col0, #T_67dd3_row3_col2, #T_67dd3_row3_col7, #T_67dd3_row4_col8, #T_67dd3_row5_col8, #T_67dd3_row7_col10, #T_67dd3_row7_col11, #T_67dd3_row8_col11, #T_67dd3_row9_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_67dd3_row0_col9, #T_67dd3_row4_col9, #T_67dd3_row5_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_67dd3_row0_col10, #T_67dd3_row4_col10, #T_67dd3_row5_col5, #T_67dd3_row5_col10, #T_67dd3_row6_col10 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_67dd3_row1_col0, #T_67dd3_row2_col0, #T_67dd3_row8_col0, #T_67dd3_row8_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_67dd3_row1_col7, #T_67dd3_row8_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_67dd3_row1_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_67dd3_row1_col10, #T_67dd3_row2_col10, #T_67dd3_row3_col10 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_67dd3_row1_col12 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_67dd3_row2_col1, #T_67dd3_row8_col12 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_67dd3_row2_col3 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col5, #T_67dd3_row6_col5, #T_67dd3_row7_col5, #T_67dd3_row8_col10, #T_67dd3_row9_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_67dd3_row2_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col7 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col8, #T_67dd3_row6_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_67dd3_row2_col9 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_67dd3_row2_col12 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_67dd3_row3_col4, #T_67dd3_row5_col4 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_67dd3_row3_col5, #T_67dd3_row3_col11, #T_67dd3_row5_col12 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_67dd3_row3_col6 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_67dd3_row3_col9 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_67dd3_row3_col12 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_67dd3_row4_col12, #T_67dd3_row6_col8 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_67dd3_row5_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_67dd3_row5_col3, #T_67dd3_row9_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_67dd3_row5_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_67dd3_row6_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_67dd3_row6_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_67dd3_row6_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_67dd3_row6_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_67dd3_row6_col6 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_67dd3_row6_col7 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_67dd3_row6_col12 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_67dd3_row7_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_67dd3_row7_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_67dd3_row7_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_67dd3_row7_col8 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_67dd3_row7_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_67dd3_row8_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_67dd3_row8_col3, #T_67dd3_row8_col8 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_67dd3_row9_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_67dd3_row9_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_67dd3_row9_col6 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_67dd3_row9_col7 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_67dd3_row9_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_67dd3_row9_col9 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# </style>
# <table id="T_67dd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67dd3_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_67dd3_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_67dd3_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_67dd3_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_67dd3_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_67dd3_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_67dd3_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_67dd3_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_67dd3_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_67dd3_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_67dd3_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_67dd3_level0_col11" class="col_heading level0 col11" >quality</th>
#       <th id="T_67dd3_level0_col12" class="col_heading level0 col12" >Id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67dd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67dd3_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_67dd3_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_67dd3_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_67dd3_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_67dd3_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_67dd3_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_67dd3_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_67dd3_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_67dd3_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_67dd3_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_67dd3_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_67dd3_row0_col11" class="data row0 col11" >5</td>
#       <td id="T_67dd3_row0_col12" class="data row0 col12" >0</td>
#     </tr>
#     <tr>
#       <th id="T_67dd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67dd3_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_67dd3_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_67dd3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_67dd3_row1_col3" class="data row1 col3" >2.6

# %%
# eliminazione della colonna [id] dal dataframe [df]

df = df.drop('Id', axis=1)
df.head(10).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_2c988_row0_col0, #T_2c988_row4_col0, #T_2c988_row5_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_2c988_row0_col1, #T_2c988_row4_col1 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_2c988_row0_col2, #T_2c988_row0_col11, #T_2c988_row1_col2, #T_2c988_row1_col11, #T_2c988_row2_col11, #T_2c988_row3_col1, #T_2c988_row3_col8, #T_2c988_row4_col2, #T_2c988_row4_col11, #T_2c988_row5_col2, #T_2c988_row5_col11, #T_2c988_row6_col9, #T_2c988_row6_col11, #T_2c988_row7_col2, #T_2c988_row7_col3, #T_2c988_row7_col4, #T_2c988_row7_col7, #T_2c988_row8_col5, #T_2c988_row8_col6, #T_2c988_row9_col0, #T_2c988_row9_col10, #T_2c988_row9_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2c988_row0_col3, #T_2c988_row3_col3, #T_2c988_row4_col3, #T_2c988_row8_col1, #T_2c988_row8_col9, #T_2c988_row9_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_2c988_row0_col4, #T_2c988_row4_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2c988_row0_col5, #T_2c988_row4_col5 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_2c988_row0_col6, #T_2c988_row4_col6 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_2c988_row0_col7, #T_2c988_row4_col7, #T_2c988_row5_col7 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_2c988_row0_col8, #T_2c988_row1_col1, #T_2c988_row1_col3, #T_2c988_row1_col4, #T_2c988_row1_col5, #T_2c988_row1_col6, #T_2c988_row1_col9, #T_2c988_row3_col0, #T_2c988_row3_col2, #T_2c988_row3_col7, #T_2c988_row4_col8, #T_2c988_row5_col8, #T_2c988_row7_col10, #T_2c988_row7_col11, #T_2c988_row8_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2c988_row0_col9, #T_2c988_row4_col9, #T_2c988_row5_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_2c988_row0_col10, #T_2c988_row4_col10, #T_2c988_row5_col5, #T_2c988_row5_col10, #T_2c988_row6_col10 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_2c988_row1_col0, #T_2c988_row2_col0, #T_2c988_row8_col0, #T_2c988_row8_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_2c988_row1_col7, #T_2c988_row8_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_2c988_row1_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_2c988_row1_col10, #T_2c988_row2_col10, #T_2c988_row3_col10 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_2c988_row2_col3 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col5, #T_2c988_row6_col5, #T_2c988_row7_col5, #T_2c988_row8_col10, #T_2c988_row9_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_2c988_row2_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col7 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_2c988_row2_col8, #T_2c988_row6_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_2c988_row2_col9 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_2c988_row3_col4, #T_2c988_row5_col4 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_2c988_row3_col5, #T_2c988_row3_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_2c988_row3_col6 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_2c988_row3_col9 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_2c988_row5_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_2c988_row5_col3, #T_2c988_row9_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_2c988_row5_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_2c988_row6_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_2c988_row6_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_2c988_row6_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_2c988_row6_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_2c988_row6_col6 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_2c988_row6_col7 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_2c988_row6_col8 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_2c988_row7_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_2c988_row7_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_2c988_row7_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_2c988_row7_col8 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_2c988_row7_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_2c988_row8_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_2c988_row8_col3, #T_2c988_row8_col8 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_2c988_row9_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_2c988_row9_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_2c988_row9_col6 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_2c988_row9_col7 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_2c988_row9_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_2c988_row9_col9 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# </style>
# <table id="T_2c988">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c988_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_2c988_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_2c988_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_2c988_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_2c988_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_2c988_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_2c988_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_2c988_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_2c988_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_2c988_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_2c988_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_2c988_level0_col11" class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c988_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c988_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_2c988_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_2c988_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2c988_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_2c988_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_2c988_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_2c988_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_2c988_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_2c988_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_2c988_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_2c988_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_2c988_row0_col11" class="data row0 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2c988_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c988_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_2c988_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_2c988_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2c988_row1_col3" class="data row1 col3" >2.600000</td>
#       <td id="T_2c988_row1_col4" class="data row1 col4" >0.098000</td>
#       <td id="T_2c988_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_2c988_row1_col6" class="data row1 col6" >67.000000</td>
#       <td id="T_2c988_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_2c988_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_2c988_row1_col9" class="data row1 col9" >0.680000</td>
#       <td id="T_2c988_row1_col10" class="data row1 col10" >9.800000</td>
#       <td id="T_2c988_row1_col11" class="d

# %%
# stampare il numero di righe e di colonne disponibili

print('sono disponibili', df.shape[0]  , 'esempi, ognuno caratterizzato da', df.shape[1], 'feature.')
# Out:
# sono disponibili 1143 esempi, ognuno caratterizzato da 12 feature.

# %%
df.describe().T
# Out:
#                        count       mean        std      min       25%
# fixed acidity         1143.0   8.311111   1.747595  4.60000   7.10000  \
# volatile acidity      1143.0   0.531339   0.179633  0.12000   0.39250
# citric acid           1143.0   0.268364   0.196686  0.00000   0.09000
# residual sugar        1143.0   2.532152   1.355917  0.90000   1.90000
# chlorides             1143.0   0.086933   0.047267  0.01200   0.07000
# free sulfur dioxide   1143.0  15.615486  10.250486  1.00000   7.00000
# total sulfur dioxide  1143.0  45.914698  32.782130  6.00000  21.00000
# density               1143.0   0.996730   0.001925  0.99007   0.99557
# pH                    1143.0   3.311015   0.156664  2.74000   3.20500
# sulphates             1143.0   0.657708   0.170399  0.33000   0.55000
# alcohol               1143.0  10.442111   1.082196  8.40000   9.50000
# quality               1143.0   5.657043   0.805824  3.00000   5.00000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.100000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.25000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   13.00000  21.000000   68.00000
# total sulfur dioxide  37.00000  61.000000  289.00000
# density                0.99668   0.997845    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
# verifica della non presenza di valori null / NaN
# sfruttando il metodo [isnull]
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# analisi del numero di valori univoci per ogni
# caratteristica, sfruttando il metodo [nunique]
df.nunique()
# Out:
# fixed acidity            91
# volatile acidity        135
# citric acid              77
# residual sugar           80
# chlorides               131
# free sulfur dioxide      53
# total sulfur dioxide    138
# density                 388
# pH                       87
# sulphates                89
# alcohol                  61
# quality                   6
# dtype: int64

# %%
# analisi della distribuzione dei dati di ogni caratteristica
# tramite istogrammi

for col in df.columns:
    
    f, (ax1) = plt.subplots(1, 1, figsize=(5, 3))
    
    valori_distribuzione = df[col]
    sns.histplot(valori_distribuzione, ax=ax1, color='orange', kde=True)

    media = df[col].mean()
    mediana = df[col].median()
    moda = df[col].mode()[0]

    ax1.axvline(media, color='red')
    ax1.axvline(mediana, color='blue')
    ax1.axvline(moda, color='green')
    
    ax1.plot()
    
    plt.grid()
    plt.title(col)

# %%
# analisi della distribuzione degli esempi disponibili
# relativamente alla qualità di ognuno tramite un
# diagramma a torta

plt.figure(figsize=(6, 6))
df['quality'].value_counts().plot(kind='pie')
plt.legend()
plt.show()

# %%
# analisi delle eventuali correlazioni
# tramite una mappa di correlazione

plt.figure(figsize=(5, 4))
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="Blues")
plt.show()

# %% [markdown]
# ## creazione del dataset

# %%
df

# %%
df.iloc[:, :-1].values

# %%
df.iloc[:, -1:].values

# %%
# creare il dataset [x] con tutte le colonne
# del dataframe [df] eccetto la colonna [quality]
x = df.iloc[:, :-1].values

# creare il dataset [y] usando la colonna
# [quality] del dataframe [df]
y = df.iloc[:, -1:].values

print('x', type(x), x.shape)
print('y', type(y), y.shape)
# Out:
# x <class 'numpy.ndarray'> (1143, 11)
# y <class 'numpy.ndarray'> (1143, 1)

# %%
# si può riprovare a lanciare il notebook mischiando
# il dataset prima di addestrare il modello

#x, y = shuffle(x, y)

# %%
# utilizzare i primi 1000 esempi per addestrare il
# modello e i restanti 143 esempi per validarlo

split = 1000

x_train = x[:split]
y_train = y[:split]

x_test = x[split:]
y_test = y[split:]

print(x_train.shape)
print(y_train.shape)
print("---")
print(x_test.shape)
print(y_test.shape)
# Out:
# (1000, 11)
# (1000, 1)
# ---
# (143, 11)
# (143, 1)

# %%
# normalizzare il dataset tra 0 e 1
# calcolando i valori su cui normalizzare
# sul solo dataset di addestramento
scaler = MinMaxScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(x_train.shape)
print(y_train.shape)
print("---")
print(x_test.shape)
print(y_test.shape)
# Out:
# (1000, 11)
# (1000, 1)
# ---
# (143, 11)
# (143, 1)

# %% [markdown]
# ## definizione del modello predittivo

# %%
# implementare una rete neurale artificiale
# con tre layer nascosti, ognuno con 8 neuroni
# e utilizzare la funzione di attivazione ReLu
# per ognuno di questi

inputs = tf.keras.Input(shape=(x_train.shape[1]))

layer_1 = tf.keras.layers.Dense(units=8, activation='relu')(inputs)
layer_2 = tf.keras.layers.Dense(units=8, activation='relu')(layer_1)
layer_3 = tf.keras.layers.Dense(units=8, activation='relu')(layer_2)

outputs = tf.keras.layers.Dense(1)(layer_3)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.mean_squared_error,
    metrics=tf.keras.metrics.mean_absolute_error
)

# visualizzare il sommario del modello
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 11)]              0
#
#  dense_4 (Dense)             (None, 8)                 96
#
#  dense_5 (Dense)             (None, 8)                 72
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 249
# Trainable params: 249
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import utils

utils.plot_model(
    model, 
    show_shapes=True
)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# addestrare il modello su 100 epoche
# sfruttando il dataset [x_test, y_test]
# per validare il modello ad ogni
# epoca
log = model.fit(
    x_train,
    y_train,
    epochs=100,
    validation_data=(x_test, y_test),
    verbose=2,
    batch_size=64
)
# Out:
# Epoch 1/100
# /home/thenoisesculptor/programming/datamaster/venv/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 16/16 - 1s - loss: 8.9009 - mean_absolute_error: 2.2032 - val_loss: 0.6720 - val_mean_absolute_error: 0.6190 - 710ms/epoch - 44ms/step
# Epoch 2/100
# 16/16 - 1s - loss: 0.5452 - mean_absolute_error: 0.5926 - val_loss: 0.6413 - val_mean_absolute_error: 0.6098 - 597ms/epoch - 37ms/step
# Epoch 3/100
# 16/16 - 1s - loss: 0.5297 - mean_absolute_error: 0.5851 - val_loss: 0.6312 - val_mean_absolute_error: 0.6041 - 592ms/epoch - 37ms/step
# Epoch 4/100
# 16/16 - 1s - loss: 0.5156 - mean_absolute_error: 0.5771 - val_loss: 0.6157 - val_mean_absolute_error: 0.5983 - 618ms/epoch - 39ms/step
# Epoch 5/100
# 16/16 - 1s - loss: 0.5015 - mean_absolute_error: 0.5674 - val_loss: 0.5931 - val_mean_absolute_error: 0.5949 - 573ms/epoch - 36ms/step
# Epoch 6/100
# 16/16 - 1s - loss: 0.4927 - mean_absolute_error: 0.5607 - val_loss: 0.5829 - val_mean_absolute_error: 0.5887 - 539ms/epoch - 34ms/step
# Epoch 7/100
# 16/16 - 1s - loss: 0.4823 - mean_absolute_error: 0.5569 - val_loss: 0.5821 - val_mean_absolute_error: 0.5832 - 591ms/epoch - 37ms/step
# Epoch 8/100
# 16/16 - 1s - loss: 0.4740 - mean_absolute_error: 0.5486 - val_loss: 0.5706 - val_mean_absolute_error: 0.5789 - 504ms/epoch - 32ms/step
# Epoch 9/100
# 16/16 - 1s - loss: 0.4625 - mean_absolute_error: 0.5412 - val_loss: 0.5796 - val_mean_absolute_error: 0.5805 - 639ms/epoch - 40ms/step
# Epoch 10/100
# 16/16 - 1s - loss: 0.4720 - mean_absolute_error: 0.5439 - val_loss: 0.5814 - val_mean_absolute_error: 0.5810 - 506ms/epoch - 32ms/step
# Epoch 11/100
# 16/16 - 1s - loss: 0.4671 - mean_absolute_error: 0.5403 - val_loss: 0.5696 - val_mean_absolute_error: 0.5749 - 622ms/epoch - 39ms/step
# Epoch 12/100
# 16/16 - 1s - loss: 0.4550 - mean_absolute_error: 0.5321 - val_loss: 0.5752 - val_mean_absolute_error: 0.5779 - 568ms/epoch - 36ms/step
# Epoch 13/100
# 16/16 - 1s - loss: 0.4481 - mean_absolute_error: 0.5298 - val_loss: 0.5466 - val_mean_absolute_error: 0.5619 - 578ms/epoch - 36ms/step
# Epoch 14/100
# 16/16 - 1s - loss: 0.4483 - mean_absolute_error: 0.5250 - val_loss: 0.5496 - val_mean_absolute_error: 0.5645 - 577ms/epoch - 36ms/step
# Epoch 15/100
# 16/16 - 1s - loss: 0.4426 - mean_absolute_error: 0.5243 - val_loss: 0.5489 - val_mean_absolute_error: 0.5636 - 552ms/epoch - 35ms/step
# Epoch 16/100
# 16/16 - 1s - loss: 0.4373 - mean_absolute_error: 0.5215 - val_loss: 0.5527 - val_mean_absolute_error: 0.5640 - 587ms/epoch - 37ms/step
# Epoch 17/100
# 16/16 - 1s - loss: 0.4398 - mean_absolute_error: 0.5193 - val_loss: 0.5879 - val_mean_absolute_error: 0.5860 - 621ms/epoch - 39ms/step
# Epoch 18/100
# 16/16 - 1s - loss: 0.4314 - mean_absolute_error: 0.5122 - val_loss: 0.5503 - val_mean_absolute_error: 0.5615 - 632ms/epoch - 39ms/step
# Epoch 19/100
# 16/16 - 1s - loss: 0.4283 - mean_absolute_error: 0.5124 - val_loss: 0.5369 - val_mean_absolute_error: 0.5548 - 627ms/epoch - 39ms/step
# Epoch 20/100
# 16/16 - 1s - loss: 0.4327 - mean_absolute_error: 0.5142 - val_loss: 0.5645 - val_mean_absolute_error: 0.5702 - 716ms/epoch - 45ms/step
# Epoch 21/100
# 16/16 - 1s - loss: 0.4255 - mean_absolute_error: 0.5129 - val_loss: 0.5364 - val_mean_absolute_error: 0.5540 - 596ms/epoch - 37ms/step
# Epoch 22/100
# 16/16 - 1s - loss: 0.4247 - mean_absolute_error: 0.5093 - val_loss: 0.5409 - val_mean_absolute_error: 0.5535 - 585ms/epoch - 37ms/step
# Epoch 23/100
# 16/16 - 1s - loss: 0.4224 - mean_absolute_error: 0.5069 - val_loss: 0.5523 - val_mean_absolute_error: 0.5624 - 603ms/epoch - 38ms/step
# Epoch 24/100
# 16/16 - 1s - loss: 0.4219 - mean_absolute_error: 0.5102 - val_loss: 0.5509 - val_mean_absolute_error: 0.5613 - 507ms/epoch - 32ms/step
# Epoch 25/100
# 16/16 - 1s - loss: 0.4237 - mean_absolute_error: 0.5080 - val_loss: 0.5350 - val_mean_absolute_error: 0.5512 - 528ms/epoch - 33ms/step
# Epoch 26/100
# 16/16 - 1s - loss: 0.4225 - mean_absolute_error: 0.5084 - val_loss: 0.5447 - val_mean_absolute_error: 0.5578 - 652ms/epoch - 41ms/step
# Epoch 27/100
# 16/16 - 1s - loss: 0.4195 - mean_absolute_error: 0.5073 - val_loss: 0.5362 - val_mean_absolute_error: 0.5502 - 588ms/epoch - 37ms/step
# Epoch 28/100
# 16/16 - 1s - loss: 0.4185 - mean_absolute_error: 0.5047 - val_loss: 0.5364 - val_mean_absolute_error: 0.5518 - 553ms/epoch - 35ms/step
# Epoch 29/100
# 16/16 - 1s - loss: 0.4163 - mean_absolute_error: 0.5022 - val_loss: 0.5653 - val_mean_absolute_error: 0.5709 - 557ms/epoch - 35ms/step
# Epoch 30/100
# 16/16 - 1s - loss: 0.4160 - mean_absolute_error: 0.5067 - val_loss: 0.5397 - val_mean_absolute_error: 0.5543 - 580ms/epoch - 36ms/step
# Epoch 31/100
# 16/16 - 1s - loss: 0.4132 - mean_absolute_error: 0.4999 - val_loss: 0.5354 - val_mean_absolute_error: 0.5499 - 615ms/epoch - 38ms/step
# Epoch 32/100
# 16/16 - 1s - loss: 0.4120 - mean_absolute_error: 0.5016 - val_loss: 0.5869 - val_mean_absolute_error: 0.5849 - 575ms/epoch - 36ms/step
# Epoch 33/100
# 16/16 - 1s - loss: 0.4142 - mean_absolute_error: 0.5046 - val_loss: 0.5680 - val_mean_absolute_error: 0.5726 - 624ms/epoch - 39ms/step
# Epoch 34/100
# 16/16 - 1s - loss: 0.4091 - mean_absolute_error: 0.5013 - val_loss: 0.5446 - val_mean_absolute_error: 0.5582 - 504ms/epoch - 31ms/step
# Epoch 35/100
# 16/16 - 1s - loss: 0.4069 - mean_absolute_error: 0.4988 - val_loss: 0.5364 - val_mean_absolute_error: 0.5520 - 570ms/epoch - 36ms/step
# Epoch 36/100
# 16/16 - 1s - loss: 0.4129 - mean_absolute_error: 0.4994 - val_loss: 0.5619 - val_mean_absolute_error: 0.5701 - 572ms/epoch - 36ms/step
# Epoch 37/100
# 16/16 - 1s - loss: 0.4114 - mean_absolute_error: 0.5034 - val_loss: 0.5353 - val_mean_absolute_error: 0.5511 - 595ms/epoch - 37ms/step
# Epoch 38/100
# 16/16 - 1s - loss: 0.4107 - mean_absolute_error: 0.5004 - val_loss: 0.5430 - val_mean_absolute_error: 0.5590 - 579ms/epoch - 36ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.4192 - mean_absolute_error: 0.5072 - val_loss: 0.5365 - val_mean_absolute_error: 0.5534 - 498ms/epoch - 31ms/step
# Epoch 40/100
# 16/16 - 1s - loss: 0.4100 - mean_absolute_error: 0.5028 - val_loss: 0.5589 - val_mean_absolute_error: 0.5694 - 575ms/epoch - 36ms/step
# Epoch 41/100
# 16/16 - 1s - loss: 0.4068 - mean_absolute_error: 0.4979 - val_loss: 0.5350 - val_mean_absolute_error: 0.5519 - 585ms/epoch - 37ms/step
# Epoch 42/100
# 16/16 - 1s - loss: 0.4057 - mean_absolute_error: 0.4970 - val_loss: 0.5418 - val_mean_absolute_error: 0.5578 - 620ms/epoch - 39ms/step
# Epoch 43/100
# 16/16 - 1s - loss: 0.4033 - mean_absolute_error: 0.4969 - val_loss: 0.5514 - val_mean_absolute_error: 0.5661 - 668ms/epoch - 42ms/step
# Epoch 44/100
# 16/16 - 1s - loss: 0.4099 - mean_absolute_error: 0.5022 - val_loss: 0.5335 - val_mean_absolute_error: 0.5501 - 608ms/epoch - 38ms/step
# Epoch 45/100
# 16/16 - 1s - loss: 0.4071 - mean_absolute_error: 0.4990 - val_loss: 0.5341 - val_mean_absolute_error: 0.5517 - 717ms/epoch - 45ms/step
# Epoch 46/100
# 16/16 - 1s - loss: 0.4021 - mean_absolute_error: 0.4944 - val_loss: 0.5541 - val_mean_absolute_error: 0.5679 - 622ms/epoch - 39ms/step
# Epoch 47/100
# 16/16 - 1s - loss: 0.4055 - mean_absolute_error: 0.4980 - val_loss: 0.5578 - val_mean_absolute_error: 0.5683 - 618ms/epoch - 39ms/step
# Epoch 48/100
# 16/16 - 1s - loss: 0.4111 - mean_absolute_error: 0.5015 - val_loss: 0.5438 - val_mean_absolute_error: 0.5610 - 623ms/epoch - 39ms/step
# Epoch 49/100
# 16/16 - 1s - loss: 0.4012 - mean_absolute_error: 0.4949 - val_loss: 0.5667 - val_mean_absolute_error: 0.5765 - 607ms/epoch - 38ms/step
# Epoch 50/100
# 16/16 - 1s - loss: 0.4002 - mean_absolute_error: 0.4968 - val_loss: 0.5446 - val_mean_absolute_error: 0.5620 - 608ms/epoch - 38ms/step
# Epoch 51/100
# 16/16 - 1s - loss: 0.4024 - mean_absolute_error: 0.4963 - val_loss: 0.5577 - val_mean_absolute_error: 0.5707 - 539ms/epoch - 34ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.3986 - mean_absolute_error: 0.4937 - val_loss: 0.5902 - val_mean_absolute_error: 0.5899 - 483ms/epoch - 30ms/step
# Epoch 53/100
# 16/16 - 1s - loss: 0.4071 - mean_absolute_error: 0.5007 - val_loss: 0.5520 - val_mean_absolute_error: 0.5671 - 587ms/epoch - 37ms/step
# Epoch 54/100
# 16/16 - 1s - loss: 0.3993 - mean_absolute_error: 0.4927 - val_loss: 0.5599 - val_mean_absolute_error: 0.5720 - 613ms/epoch - 38ms/step
# Epoch 55/100
# 16/16 - 1s - loss: 0.4017 - mean_absolute_error: 0.4939 - val_loss: 0.5878 - val_mean_absolute_error: 0.5888 - 628ms/epoch - 39ms/step
# Epoch 56/100
# 16/16 - 1s - loss: 0.3973 - mean_absolute_error: 0.4932 - val_loss: 0.5823 - val_mean_absolute_error: 0.5853 - 627ms/epoch - 39ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 0.4030 - mean_absolute_error: 0.4970 - val_loss: 0.5340 - val_mean_absolute_error: 0.5539 - 497ms/epoch - 31ms/step
# Epoch 58/100
# 16/16 - 1s - loss: 0.4028 - mean_absolute_error: 0.4955 - val_loss: 0.5314 - val_mean_absolute_error: 0.5513 - 586ms/epoch - 37ms/step
# Epoch 59/100
# 16/16 - 1s - loss: 0.3969 - mean_absolute_error: 0.4914 - val_loss: 0.5746 - val_mean_absolute_error: 0.5811 - 573ms/epoch - 36ms/step
# Epoch 60/100
# 16/16 - 1s - loss: 0.3989 - mean_absolute_error: 0.4956 - val_loss: 0.5400 - val_mean_absolute_error: 0.5590 - 551ms/epoch - 34ms/step
# Epoch 61/100
# 16/16 - 1s - loss: 0.4041 - mean_absolute_error: 0.4968 - val_loss: 0.5481 - val_mean_absolute_error: 0.5647 - 638ms/epoch - 40ms/step
# Epoch 62/100
# 16/16 - 1s - loss: 0.3967 - mean_absolute_error: 0.4927 - val_loss: 0.5948 - val_mean_absolute_error: 0.5940 - 532ms/epoch - 33ms/step
# Epoch 63/100
# 16/16 - 1s - loss: 0.3971 - mean_absolute_error: 0.4941 - val_loss: 0.5624 - val_mean_absolute_error: 0.5733 - 613ms/epoch - 38ms/step
# Epoch 64/100
# 16/16 - 1s - loss: 0.3959 - mean_absolute_error: 0.4915 - val_loss: 0.5987 - val_mean_absolute_error: 0.5974 - 616ms/epoch - 39ms/step
# Epoch 65/100
# 16/16 - 1s - loss: 0.3996 - mean_absolute_error: 0.4952 - val_loss: 0.5419 - val_mean_absolute_error: 0.5617 - 590ms/epoch - 37ms/step
# Epoch 66/100
# 16/16 - 1s - loss: 0.3952 - mean_absolute_error: 0.4928 - val_loss: 0.5533 - val_mean_absolute_error: 0.5693 - 603ms/epoch - 38ms/step
# Epoch 67/100
# 16/16 - 1s - loss: 0.3978 - mean_absolute_error: 0.4947 - val_loss: 0.5481 - val_mean_absolute_error: 0.5654 - 530ms/epoch - 33ms/step
# Epoch 68/100
# 16/16 - 1s - loss: 0.4005 - mean_absolute_error: 0.4956 - val_loss: 0.5660 - val_mean_absolute_error: 0.5770 - 595ms/epoch - 37ms/step
# Epoch 69/100
# 16/16 - 1s - loss: 0.3942 - mean_absolute_error: 0.4919 - val_loss: 0.5289 - val_mean_absolute_error: 0.5511 - 579ms/epoch - 36ms/step
# Epoch 70/100
# 16/16 - 1s - loss: 0.3949 - mean_absolute_error: 0.4910 - val_loss: 0.5625 - val_mean_absolute_error: 0.5752 - 600ms/epoch - 37ms/step
# Epoch 71/100
# 16/16 - 1s - loss: 0.3952 - mean_absolute_error: 0.4912 - val_loss: 0.5655 - val_mean_absolute_error: 0.5771 - 606ms/epoch - 38ms/step
# Epoch 72/100
# 16/16 - 1s - loss: 0.3957 - mean_absolute_error: 0.4920 - val_loss: 0.5774 - val_mean_absolute_error: 0.5842 - 572ms/epoch - 36ms/step
# Epoch 73/100
# 16/16 - 1s - loss: 0.3945 - mean_absolute_error: 0.4902 - val_loss: 0.5883 - val_mean_absolute_error: 0.5911 - 584ms/epoch - 37ms/step
# Epoch 74/100
# 16/16 - 1s - loss: 0.3997 - mean_absolute_error: 0.4923 - val_loss: 0.5428 - val_mean_absolute_error: 0.5629 - 568ms/epoch - 35ms/step
# Epoch 75/100
# 16/16 - 1s - loss: 0.3920 - mean_absolute_error: 0.4902 - val_loss: 0.5784 - val_mean_absolute_error: 0.5851 - 586ms/epoch - 37ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 0.4019 - mean_absolute_error: 0.4990 - val_loss: 0.5315 - val_mean_absolute_error: 0.5542 - 485ms/epoch - 30ms/step
# Epoch 77/100
# 16/16 - 1s - loss: 0.3972 - mean_absolute_error: 0.4941 - val_loss: 0.5260 - val_mean_absolute_error: 0.5492 - 521ms/epoch - 33ms/step
# Epoch 78/100
# 16/16 - 1s - loss: 0.3945 - mean_absolute_error: 0.4902 - val_loss: 0.5957 - val_mean_absolute_error: 0.5963 - 588ms/epoch - 37ms/step
# Epoch 79/100
# 16/16 - 1s - loss: 0.3946 - mean_absolute_error: 0.4960 - val_loss: 0.5378 - val_mean_absolute_error: 0.5602 - 623ms/epoch - 39ms/step
# Epoch 80/100
# 16/16 - 1s - loss: 0.4010 - mean_absolute_error: 0.4958 - val_loss: 0.5351 - val_mean_absolute_error: 0.5575 - 600ms/epoch - 37ms/step
# Epoch 81/100
# 16/16 - 1s - loss: 0.3964 - mean_absolute_error: 0.4939 - val_loss: 0.5307 - val_mean_absolute_error: 0.5548 - 579ms/epoch - 36ms/step
# Epoch 82/100
# 16/16 - 1s - loss: 0.3941 - mean_absolute_error: 0.4892 - val_loss: 0.5476 - val_mean_absolute_error: 0.5664 - 511ms/epoch - 32ms/step
# Epoch 83/100
# 16/16 - 1s - loss: 0.3951 - mean_absolute_error: 0.4905 - val_loss: 0.5545 - val_mean_absolute_error: 0.5701 - 596ms/epoch - 37ms/step
# Epoch 84/100
# 16/16 - 1s - loss: 0.3899 - mean_absolute_error: 0.4878 - val_loss: 0.5793 - val_mean_absolute_error: 0.5861 - 602ms/epoch - 38ms/step
# Epoch 85/100
# 16/16 - 1s - loss: 0.3960 - mean_absolute_error: 0.4937 - val_loss: 0.5346 - val_mean_absolute_error: 0.5582 - 634ms/epoch - 40ms/step
# Epoch 86/100
# 16/16 - 1s - loss: 0.3890 - mean_absolute_error: 0.4880 - val_loss: 0.5445 - val_mean_absolute_error: 0.5646 - 585ms/epoch - 37ms/step
# Epoch 87/100
# 16/16 - 1s - loss: 0.3923 - mean_absolute_error: 0.4902 - val_loss: 0.5242 - val_mean_absolute_error: 0.5491 - 584ms/epoch - 36ms/step
# Epoch 88/100
# 16/16 - 1s - loss: 0.3934 - mean_absolute_error: 0.4894 - val_loss: 0.5497 - val_mean_absolute_error: 0.5672 - 579ms/epoch - 36ms/step
# Epoch 89/100
# 16/16 - 1s - loss: 0.3904 - mean_absolute_error: 0.4875 - val_loss: 0.5752 - val_mean_absolute_error: 0.5838 - 588ms/epoch - 37ms/step
# Epoch 90/100
# 16/16 - 1s - loss: 0.3971 - mean_absolute_error: 0.4922 - val_loss: 0.5657 - val_mean_absolute_error: 0.5773 - 515ms/epoch - 32ms/step
# Epoch 91/100
# 16/16 - 1s - loss: 0.3935 - mean_absolute_error: 0.4922 - val_loss: 0.5490 - val_mean_absolute_error: 0.5669 - 605ms/epoch - 38ms/step
# Epoch 92/100
# 16/16 - 1s - loss: 0.3929 - mean_absolute_error: 0.4927 - val_loss: 0.5584 - val_mean_absolute_error: 0.5721 - 586ms/epoch - 37ms/step
# Epoch 93/100
# 16/16 - 1s - loss: 0.3918 - mean_absolute_error: 0.4897 - val_loss: 0.6353 - val_mean_absolute_error: 0.6193 - 591ms/epoch - 37ms/step
# Epoch 94/100
# 16/16 - 1s - loss: 0.3986 - mean_absolute_error: 0.4974 - val_loss: 0.5260 - val_mean_absolute_error: 0.5512 - 584ms/epoch - 36ms/step
# Epoch 95/100
# 16/16 - 1s - loss: 0.3876 - mean_absolute_error: 0.4835 - val_loss: 0.5454 - val_mean_absolute_error: 0.5657 - 624ms/epoch - 39ms/step
# Epoch 96/100
# 16/16 - 1s - loss: 0.3929 - mean_absolute_error: 0.4909 - val_loss: 0.5236 - val_mean_absolute_error: 0.5512 - 596ms/epoch - 37ms/step
# Epoch 97/100
# 16/16 - 1s - loss: 0.3921 - mean_absolute_error: 0.4883 - val_loss: 0.5627 - val_mean_absolute_error: 0.5764 - 594ms/epoch - 37ms/step
# Epoch 98/100
# 16/16 - 1s - loss: 0.3894 - mean_absolute_error: 0.4885 - val_loss: 0.5359 - val_mean_absolute_error: 0.5600 - 582ms/epoch - 36ms/step
# Epoch 99/100
# 16/16 - 1s - loss: 0.3911 - mean_absolute_error: 0.4908 - val_loss: 0.5408 - val_mean_absolute_error: 0.5625 - 577ms/epoch - 36ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 0.3913 - mean_absolute_error: 0.4889 - val_loss: 0.5404 - val_mean_absolute_error: 0.5622 - 489ms/epoch - 31ms/step

# %%
log.history.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
# visualizzazione dell'andamento dell'errore
# durante l'addestramento

plt.figure(figsize=(6, 6))
plt.title('Errore quadratico medio')

plt.ylim(min(log.history['loss']), min(log.history['loss']) +  min(log.history['loss'])*1 )


plt.plot(log.history['loss'], label='train')
plt.plot(log.history['val_loss'], label='test')

plt.xlabel('epoche')
plt.ylabel('errore')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.title('Errore medio in valore assoluto')
plt.plot(log.history['mean_absolute_error'], label='train')
plt.plot(log.history['val_mean_absolute_error'], label='test')

plt.xlabel('epoche')
plt.ylabel('errore')
plt.legend()
plt.show()

# %%
# recupero dati di validazione del modello
# ovvero l'errore quadratico medio e l'errore
# medio in valore assoluto del modello sul
# dataset di test
eval = model.evaluate(x_test, y_test)
print(eval)
# Out:
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5404 - mean_absolute_error: 0.5622
# [0.5403934717178345, 0.5621790289878845]

# %%
# effettuare predizioni sul dataset
# di validazione
preds = model.predict(x_test)
preds
# Out:
# 5/5 [==============================] - 0s 7ms/step
# array([[6.805007 ],
#        [5.9575777],
#        [5.4751596],
#        [5.9751325],
#        [6.4135   ],
#        [5.7371054],
#        [5.705587 ],
#        [5.595525 ],
#        [5.705587 ],
#        [6.4722366],
#        [5.3784018],
#        [5.0300245],
#        [5.3784018],
#        [5.415142 ],
#        [5.946601 ],
#        [5.766383 ],
#        [6.032214 ],
#        [5.5665503],
#        [6.527435 ],
#        [5.790209 ],
#        [5.4961605],
#        [5.826951 ],
#        [5.1036477],
#        [4.97573  ],
#        [5.514783 ],
#        [5.466553 ],
#        [5.513888 ],
#        [5.944627 ],
#        [4.927595 ],
#        [5.365651 ],
#        [6.2650185],
#        [6.2441497],
#        [6.165821 ],
#        [5.954984 ],
#        [6.077091 ],
#        [5.502755 ],
#        [5.1882644],
#        [6.0674663],
#        [6.6994777],
#        [5.6439705],
#        [5.3273745],
#        [5.523075 ],
#        [5.427396 ],
#        [5.5667114],
#        [5.251975 ],
#        [5.5667114],
#        [4.9191017],
#        [5.2465806],
#        [6.0229735],
#        [6.24464  ],
#        [5.667042 ],
#        [5.1046553],
#        [6.6048584],
#        [5.1046553],
#        [6.611357 ],
#        [5.1815352],
#        [5.9088864],
#        [5.5453863],
#        [5.9088864],
#        [6.1600533],
#        [5.336324 ],
#        [5.5600996],
#        [5.8158426],
#        [5.9345965],
#        [6.6487355],
#        [5.919315 ],
#        [5.1451907],
#        [5.874987 ],
#        [5.9825263],
#        [5.7873406],
#        [5.7873406],
#        [4.99761  ],
#        [6.094188 ],
#        [6.0804195],
#        [5.3873787],
#        [5.5964074],
#        [6.0804195],
#        [5.874672 ],
#        [6.4686055],
#        [5.762089 ],
#        [5.3792   ],
#        [5.0591736],
#        [5.0643244],
#        [5.8202267],
#        [5.744755 ],
#        [5.3549757],
#        [6.1634245],
#        [5.6466274],
#        [5.5471106],
#        [5.532898 ],
#        [5.745569 ],
#        [5.3712344],
#        [6.104193 ],
#        [5.489658 ],
#        [5.639329 ],
#        [5.3290005],
#        [6.015072 ],
#        [5.4423823],
#        [5.9295297],
#        [5.9416933],
#        [6.408565 ],
#        [5.6095295],
#        [5.5450306],
#        [5.8074656],
#        [6.2633896],
#        [5.12081  ],
#        [5.6232123],
#        [5.1293283],
#        [5.8112125],
#        [5.1789184],
#        [5.4675364],
#        [4.8447804],
#        [5.122223 ],
#        [5.122223 ],
#        [5.122223 ],
#        [5.410243 ],
#        [5.410243 ],
#        [5.8077197],
#        [6.3407536],
#        [5.410243 ],
#        [5.2594905],
#        [5.9459934],
#        [6.5581236],
#        [6.057278 ],
#        [5.055593 ],
#        [6.133706 ],
#        [6.2083435],
#        [6.2161994],
#        [5.8715324],
#        [5.8000774],
#        [6.301951 ],
#        [5.800519 ],
#        [5.40631  ],
#        [6.46913  ],
#        [6.4017406],
#        [5.773683 ],
#        [6.176452 ],
#        [5.7062645],
#        [5.9011745],
#        [5.5177784],
#        [5.5230355],
#        [5.8977194],
#        [5.564676 ]], dtype=float32)

# %%
# stampa del confronto tra valori reali e predetti
# su 10 esempi a caso del dataset di test
# utilizzare il valore dell'errore medio riscontrato
# in validazione del modello come offset rispetto
# al volore predetto per definire l'intervallo
# relativo alla "risposta del modello"
for _ in range(10):
    
    id = np.random.randint(0, len(x_test))
    
    print('predetto:', preds[id][0], ' | ', int( preds[id][0] - eval[1]), '-', int(preds[id][0] + eval[1]), '\treale:', y_test[id])
# Out:
# predetto: 5.5453863  |  4 - 6 	reale: [4]
# predetto: 5.8112125  |  5 - 6 	reale: [7]
# predetto: 5.8715324  |  5 - 6 	reale: [6]
# predetto: 5.336324  |  4 - 5 	reale: [5]
# predetto: 5.122223  |  4 - 5 	reale: [5]
# predetto: 4.9191017  |  4 - 5 	reale: [3]
# predetto: 5.8000774  |  5 - 6 	reale: [6]
# predetto: 5.365651  |  4 - 5 	reale: [5]
# predetto: 5.1046553  |  4 - 5 	reale: [5]
# predetto: 5.40631  |  4 - 5 	reale: [5]
